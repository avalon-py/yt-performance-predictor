# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/full_dataset.csv")

# %%
df["channel_ref"].value_counts().head(20)
# Out:
# channel_ref
# @penguinz0                  1415
# @RealCivilEngineerGaming     600
# @ludwig                      520
# @dangerouslyfunny            451
# @theneedledrop               450
# @linustechtips               449
# @ishowspeed                  307
# @valkyrae                    282
# @GamersNexus                 273
# @SortedFood                  271
# @RickBeato                   223
# @markiplier                  207
# @FirstWeFeast                207
# @doctormike                  176
# @MythicalKitchen             167
# @CorridorCrew                139
# @doro44c                     136
# @ksi                         115
# @jacksepticeye               113
# @twosetviolin                105
# Name: count, dtype: int64

# %%
print(df["genre"].value_counts())
# Out:
# genre
# Gaming                  3180
# Entertainment           2783
# Science & Technology    1171
# Education                819
# Music                    760
# Howto & Style            265
# Autos & Vehicles         261
# People & Blogs           243
# Comedy                   141
# News & Politics           75
# Sports                    59
# Travel & Events           54
# Film & Animation          29
# Name: count, dtype: int64

# %%
print(df["genre"].value_counts(normalize=True))
# Out:
# genre
# Gaming                  0.323171
# Entertainment           0.282825
# Science & Technology    0.119004
# Education               0.083232
# Music                   0.077236
# Howto & Style           0.026931
# Autos & Vehicles        0.026524
# People & Blogs          0.024695
# Comedy                  0.014329
# News & Politics         0.007622
# Sports                  0.005996
# Travel & Events         0.005488
# Film & Animation        0.002947
# Name: proportion, dtype: float64

# %%
df["target"].describe()
df["target"].hist(bins=50)
# Out:
# <Axes: >

# %%
print(np.log1p(df["subscriber_count_at_upload"]).describe())
# Out:
# count    9840.000000
# mean       15.706093
# std         1.187716
# min        11.989166
# 25%        14.869823
# 50%        15.580242
# 75%        16.722412
# max        20.065486
# Name: subscriber_count_at_upload, dtype: float64
